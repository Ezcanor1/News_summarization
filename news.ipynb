# %%
import tkinter as tk
import nltk
from textblob import TextBlob
from newspaper import Article
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sanyd\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
url='https://indianexpress.com/section/india/'
article =Article(url)
article.download()
article.parse()
article.nlp()
print(f"Title:{article.title}")
print(f"author:{article.authors}")
print(f"publish Date:{article.publish_date}")
print(f"summary:{article.summary}")
# Out:
# Title:India News: Latest News India, Today Breaking News Headlines from India and Updates in Bharat
# author:[]
# publish Date:None
# summary:Technology August 10, 2024 20:16 ISTCisco is planning a new round of layoffs, likely affecting a similar number of employees as the 4,000 laid off earlier this year.
# The company is prioritizing growth in cybersecurity and AI, and has been acquiring and investing in the AI industry.
# This follows a trend in the tech industry of cutting costs to fund AI initiatives.

# %%
analysis=TextBlob(article.text)
print(analysis.polarity)
print(f'sentiment:{"positive "if analysis.polarity>0 else "negative" if analysis.polarity<0 else "neutral"}')
# Out:
# -0.1106060606060606
# sentiment:negative
